# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanmk-1999/Subpixel_Shift_CNN/blob/main/subpixel_shift_cnn_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN Regression: Predict Subpixel Shift

# %% [markdown]
# In a *regression* problem, the aim is to predict the output of a continuous value, like a price or a probability. Contrast this with a *classification* problem, where the aim is to select a class from a list of classes.
#
# This notebook trains a CNN to predict **subpixel-level X and Y shifts** directly from images. The ground truth shifts are embedded in each filename — for example:
#
# - `test_1_81945_3_93417.png`  →  shift_x = **1.81945**,  shift_y = **3.93417**
#
# We will follow the general machine learning workflow:
# 1. Examine and understand data
# 2. Build an input pipeline with `ImageDataGenerator`
# 3. Build our model
# 4. Train our model
# 5. Test our model

# %% [markdown]
# # Importing packages

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau

print(tf.__version__)
# Out:
# 2.19.0

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path
from sklearn.model_selection import train_test_split

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# # Data Loading

# %% [markdown]
# Mount Google Drive and point to your image folders:
# - `train_dir` — folder with your ~800 training images
# - `val_dir`   — folder with your 100 dedicated validation images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_dir = '/content/drive/MyDrive/Subpixel_Shift_CNN/train_dataset'
val_dir   = '/content/drive/MyDrive/Subpixel_Shift_CNN/val_dataset'
test_dir = '/content/drive/MyDrive/Subpixel_Shift_CNN/test_dataset'

# %% [markdown]
# # Check if the drive is mounted properly.

# %%
print(f"Checking path: {train_dir}")
if os.path.exists(train_dir):
    files = os.listdir(train_dir)
    print(f"Found {len(files)} total files in directory.")
    if len(files) > 0:
        print("First 5 files look like this:")
        print(files[:5])
else:
    print("WARNING: Directory does not exist. (Drive might not be mounted!)")
# Out:
# Checking path: /content/drive/MyDrive/Subpixel_Shift_CNN/train_dataset
# Found 800 total files in directory.
# First 5 files look like this:
# ['test_0.12915_1.22835.png', 'test_0.01597_0.16020.png', 'test_0.03372_2.81640.png', 'test_1.55044_0.90950.png', 'test_1.27176_2.90155.png']

# %% [markdown]
# ### Understanding our data
#
# The ground truth shift values are encoded directly in the filename:
#
# `test_1_81945_3_93417.png`  →  `shift_x = 1.81945`,  `shift_y = 3.93417`
#
# Let's parse all filenames and build a DataFrame.

# %%
def parse_filename(fname):
    """Extract (shift_x, shift_y) from a filename like test_0.12915_1.22835.png"""
    stem = Path(fname).stem

    m = re.match(r'^test_(-?\d+\.\d+)_(-?\d+\.\d+)$', stem)

    if m:
        sx, sy = m.groups()
        return float(sx), float(sy)

    return None, None

def load_labels_from_dir(directory):
    """Return a DataFrame with filepath, shift_x, shift_y for every PNG in directory."""
    records = []
    for fpath in sorted(Path(directory).glob('*.png')):
        sx, sy = parse_filename(fpath.name)
        if sx is not None:
            records.append({'filepath': str(fpath), 'shift_x': sx, 'shift_y': sy})
    return pd.DataFrame(records)

# %%
train_df = load_labels_from_dir(train_dir)
val_df   = load_labels_from_dir(val_dir)
test_df = load_labels_from_dir(test_dir)

total_train = len(train_df)
total_val   = len(val_df)
total_test  = len(test_df)

print('Total training images  :', total_train)
print('Total validation images:', total_val)
print('Total test images      :', total_test)
# Out:
# Total training images  : 800
# Total validation images: 100
# Total test images      : 100

# %%
train_df.describe().transpose()
# Out:
#          count      mean       std      min       25%       50%       75%  \
# shift_x  800.0  2.621467  1.408476  0.01597  1.449882  2.664835  3.832222
# shift_y  800.0  2.548603  1.501028  0.00123  1.240102  2.556070  3.861105
#
#              max
# shift_x  4.99739
# shift_y  4.99975

# %% [markdown]
# # Setting Model Parameters
#
# For convenience, set up variables that will be used while pre-processing our dataset and training our network.

# %%
BATCH_SIZE = 32
IMG_HEIGHT  = 300  # Our training data consists of images resized to IMG_SHAPE x IMG_SHAPE pixels
IMG_WIDTH = 363

# %% [markdown]
# # Data Augmentation
#
# Overfitting often occurs when we have a small number of training examples. One way to fix this problem is to augment our dataset so that it has sufficient number and variety of training examples. `ImageDataGenerator` takes care of applying augmentations to the dataset during training.
#
# **Important for this task:** because we are predicting spatial shifts, we must **not** apply spatial transforms such as flips, rotations, or translations — these would corrupt the ground truth labels. We only apply safe photometric augmentations.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20, 20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Applying brightness augmentation

# %%
image_gen = ImageDataGenerator(rescale=1./255, brightness_range=[0.8, 1.2])

# %% [markdown]
# ### Putting it all together
#
# Here, we apply rescaling and brightness augmentation for training. For validation and test we only rescale — augmentation should never be applied to validation or test images.

# %%
image_gen_train = ImageDataGenerator(
    rescale=1./255,
    brightness_range=[0.85, 1.15],   # safe photometric augmentation only
)

image_gen_val = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ### Custom data generator
#
# Since our regression labels come from filenames rather than subfolder names, we write a simple `tf.keras.utils.Sequence` that uses `ImageDataGenerator` internally and yields continuous `[shift_x, shift_y]` labels.

# %%
class SubpixelDataGenerator(tf.keras.utils.Sequence):
    """Loads images using ImageDataGenerator and yields (images, [shift_x, shift_y]) batches."""

    def __init__(self, dataframe, image_data_generator, img_height, img_width, batch_size, shuffle=False):
        self.df             = dataframe.reset_index(drop=True)
        self.gen            = image_data_generator
        self.img_height     = img_height
        self.img_width      = img_width
        self.batch_size     = batch_size
        self.shuffle        = shuffle
        self.indexes        = np.arange(len(self.df))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))

    def __getitem__(self, idx):
        batch_idx = self.indexes[idx * self.batch_size : (idx + 1) * self.batch_size]
        batch     = self.df.iloc[batch_idx]

        images, labels = [], []
        for _, row in batch.iterrows():
            img = tf.keras.utils.load_img(
                row['filepath'], target_size=(self.img_height, self.img_width)
            )
            img = tf.keras.utils.img_to_array(img)
            img = self.gen.random_transform(img)   # apply augmentation
            img = self.gen.standardize(img)        # apply rescale=1./255
            images.append(img)
            labels.append([row['shift_x'], row['shift_y']])

        return np.array(images), np.array(labels, dtype=np.float32)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %%
train_data_gen = SubpixelDataGenerator(
    train_df, image_gen_train, IMG_HEIGHT, IMG_WIDTH, BATCH_SIZE, shuffle=True
)

val_data_gen = SubpixelDataGenerator(
    val_df, image_gen_val, IMG_HEIGHT, IMG_WIDTH, BATCH_SIZE, shuffle=False
)

test_data_gen = SubpixelDataGenerator(
    test_df, image_gen_val, IMG_HEIGHT, IMG_WIDTH, BATCH_SIZE, shuffle=False
)

# %% [markdown]
# Let's visualize a few training images to confirm the pipeline is working:

# %%
sample_images, sample_labels = train_data_gen[0]
plotImages(sample_images[:5])
print('shift_x, shift_y for first 5 samples:')
print(sample_labels[:5])
# Out:
# shift_x, shift_y for first 5 samples:
# [[1.026 4.625]
#  [0.867 2.357]
#  [4.35  1.164]
#  [4.928 1.671]
#  [2.17  0.394]]

# %% [markdown]
# # Model Creation
#
# ## Define the model
#
# The model consists of four convolution blocks with a max pool layer in each of them.
#
# Before the final Dense layers, we apply a Dropout probability of 0.5 to prevent overfitting.
#
# The output layer has **2 units with no activation** (linear) to produce continuous predictions for `shift_x` and `shift_y` — this is the standard setup for regression, as used in the fuel efficiency notebook.

# %%
model = tf.keras.models.Sequential([
    # Block 1
    tf.keras.layers.Conv2D(32, (3, 3), input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    # Block 2
    tf.keras.layers.Conv2D(64, (3, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    # Block 3
    tf.keras.layers.Conv2D(128, (3, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    # Block 4
    tf.keras.layers.Conv2D(128, (3, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    # Block 5
    tf.keras.layers.Conv2D(256, (3, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Flatten(),

    # Reduced Dropout so we don't destroy the spatial math
    tf.keras.layers.Dropout(0.2),

    # Expanded final brain power
    tf.keras.layers.Dense(512),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),

    tf.keras.layers.Dense(128, activation='relu'), # Added an extra layer to refine the numbers
    tf.keras.layers.Dense(2)
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Compiling the model
#
# We use the `adam` optimizer. Since this is a regression problem we use `mean_absolute_error` as the loss function — the same loss used in the fuel efficiency regression notebook.

# %%
model.compile(optimizer='adam',
              loss='huber')

# %% [markdown]
# ### Model Summary
#
# Let's look at all the layers of our network using the `summary` method.

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_13 (Conv2D)              │ (None, 298, 361, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 298, 361, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 298, 361, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 149, 180, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 147, 178, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 147, 178, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 147, 178, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 73, 89, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 71, 87, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 71, 87, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 71, 87, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 35, 43, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 33, 41, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 33, 41, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 33, 41, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 16, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 14, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 18, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 14, 18, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 7, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 16128)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16128)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │     8,258,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,864,450 (33.82 MB)
#  Trainable params: 8,862,210 (33.81 MB)
#  Non-trainable params: 2,240 (8.75 KB)

# %% [markdown]
# # Create a Scheduler

# %%
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,       # Divide learning rate by 5
    patience=5,       # Wait 5 epochs before dropping
    min_lr=1e-7,      # Don't go lower than this
    verbose=1         # Print a message when it drops
)

# %% [markdown]
# ### Train the model

# %%
epochs = 100
history_v2 = model.fit(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE))),
    callbacks=[lr_scheduler]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 429ms/step - loss: 0.4843 - val_loss: 0.9667 - learning_rate: 0.0010
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - loss: 0.1580 - val_loss: 0.7645 - learning_rate: 0.0010
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 349ms/step - loss: 0.1464 - val_loss: 1.5428 - learning_rate: 0.0010
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 359ms/step - loss: 0.1520 - val_loss: 1.0131 - learning_rate: 0.0010
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 318ms/step - loss: 0.1065 - val_loss: 1.1744 - learning_rate: 0.0010
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - loss: 0.0916 - val_loss: 0.9795 - learning_rate: 0.0010
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.0922
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - loss: 0.1067 - val_loss: 1.0460 - learning_rate: 0.0010
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - loss: 0.0686 - val_loss: 0.9607 - learning_rate: 2.0000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 363ms/step - loss: 0.0503 - val_loss: 0.9457 - learning_rate: 2.0000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 300ms/step - loss: 0.0790 - val_loss: 0.8910 - learning_rate: 2.0000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 362ms/step - loss: 0.0521 - val_loss: 0.9562 - learning_rate: 2.0000e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - loss: 0.0650
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 371ms/step - loss: 0.0602 - val_loss: 0.8560 - learning_rate: 2.0000e-04
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - loss: 0.0556 - val_loss: 0.8712 - learning_rate: 4.0000e-05
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 370ms/step - loss: 0.0542 - val_loss: 0.8205 - learning_rate: 4.0000e-05
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 342ms/step - loss: 0.0451 - val_loss: 0.6669 - learning_rate: 4.0000e-05
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 345ms/step - loss: 0.0529 - val_loss: 0.5339 - learning_rate: 4.0000e-05
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 367ms/step - loss: 0.0433 - val_loss: 0.4550 - learning_rate: 4.0000e-05
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.0483 - val_loss: 0.2813 - learning_rate: 4.0000e-05
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 352ms/step - loss: 0.0442 - val_loss: 0.0923 - learning_rate: 4.0000e-05
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - loss: 0.0494 - val_loss: 0.0712 - learning_rate: 4.0000e-05
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - loss: 0.0527 - val_loss: 0.0201 - learning_rate: 4.0000e-05
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 355ms/step - loss: 0.0456 - val_loss: 0.0101 - learning_rate: 4.0000e-05
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 331ms/step - loss: 0.0379 - val_loss: 0.0057 - learning_rate: 4.0000e-05
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 338ms/step - loss: 0.0451 - val_loss: 0.0028 - learning_rate: 4.0000e-05
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 360ms/step - loss: 0.0461 - val_loss: 0.0058 - learning_rate: 4.0000e-05
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - loss: 0.0499 - val_loss: 0.0072 - learning_rate: 4.0000e-05
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 354ms/step - loss: 0.0440 - val_loss: 0.0052 - learning_rate: 4.0000e-05
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - loss: 0.0385 - val_loss: 0.0087 - learning_rate: 4.0000e-05
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - loss: 0.0430
# Epoch 29: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 336ms/step - loss: 0.0411 - val_loss: 0.0068 - learning_rate: 4.0000e-05
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 348ms/step - loss: 0.0479 - val_loss: 0.0061 - learning_rate: 8.0000e-06
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 319ms/step - loss: 0.0465 - val_loss: 0.0054 - learning_rate: 8.0000e-06
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 342ms/step - loss: 0.0392 - val_loss: 0.0044 - learning_rate: 8.0000e-06
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 339ms/step - loss: 0.0424 - val_loss: 0.0042 - learning_rate: 8.0000e-06
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0459
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - loss: 0.0421 - val_loss: 0.0040 - learning_rate: 8.0000e-06
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 351ms/step - loss: 0.0381 - val_loss: 0.0034 - learning_rate: 1.6000e-06
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 312ms/step - loss: 0.0345 - val_loss: 0.0033 - learning_rate: 1.6000e-06
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 350ms/step - loss: 0.0489 - val_loss: 0.0031 - learning_rate: 1.6000e-06
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - loss: 0.0392 - val_loss: 0.0031 - learning_rate: 1.6000e-06
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.0475
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 340ms/step - loss: 0.0414 - val_loss: 0.0032 - learning_rate: 1.6000e-06
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 343ms/step - loss: 0.0414 - val_loss: 0.0031 - learning_rate: 3.2000e-07
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - loss: 0.0404 - val_loss: 0.0031 - learning_rate: 3.2000e-07
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 308ms/step - loss: 0.0345 - val_loss: 0.0029 - learning_rate: 3.2000e-07
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 372ms/step - loss: 0.0466 - val_loss: 0.0030 - learning_rate: 3.2000e-07
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - loss: 0.0410
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-07.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 334ms/step - loss: 0.0435 - val_loss: 0.0029 - learning_rate: 3.2000e-07
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 326ms/step - loss: 0.0412 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - loss: 0.0409 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - loss: 0.0425 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 328ms/step - loss: 0.0379 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 340ms/step - loss: 0.0381 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 297ms/step - loss: 0.0432 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 335ms/step - loss: 0.0344 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 342ms/step - loss: 0.0405 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - loss: 0.0445 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 345ms/step - loss: 0.0490 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - loss: 0.0480 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 352ms/step - loss: 0.0390 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - loss: 0.0510 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 296ms/step - loss: 0.0386 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 348ms/step - loss: 0.0369 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 337ms/step - loss: 0.0491 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 339ms/step - loss: 0.0353 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 341ms/step - loss: 0.0396 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 311ms/step - loss: 0.0411 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 319ms/step - loss: 0.0385 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - loss: 0.0460 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - loss: 0.0543 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 336ms/step - loss: 0.0439 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 350ms/step - loss: 0.0559 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - loss: 0.0395 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 337ms/step - loss: 0.0358 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 309ms/step - loss: 0.0409 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 348ms/step - loss: 0.0338 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - loss: 0.0361 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 321ms/step - loss: 0.0440 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 336ms/step - loss: 0.0425 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 311ms/step - loss: 0.0467 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - loss: 0.0378 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - loss: 0.0431 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 336ms/step - loss: 0.0427 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - loss: 0.0459 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 309ms/step - loss: 0.0396 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 353ms/step - loss: 0.0431 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 340ms/step - loss: 0.0412 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 326ms/step - loss: 0.0403 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 334ms/step - loss: 0.0431 - val_loss: 0.0027 - learning_rate: 1.0000e-07
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 301ms/step - loss: 0.0425 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 338ms/step - loss: 0.0440 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - loss: 0.0492 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 340ms/step - loss: 0.0406 - val_loss: 0.0028 - learning_rate: 1.0000e-07
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 351ms/step - loss: 0.0402 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 313ms/step - loss: 0.0420 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 351ms/step - loss: 0.0394 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - loss: 0.0468 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 326ms/step - loss: 0.0369 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 353ms/step - loss: 0.0402 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - loss: 0.0413 - val_loss: 0.0030 - learning_rate: 1.0000e-07
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - loss: 0.0468 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - loss: 0.0407 - val_loss: 0.0029 - learning_rate: 1.0000e-07
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - loss: 0.0322 - val_loss: 0.0030 - learning_rate: 1.0000e-07
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 350ms/step - loss: 0.0403 - val_loss: 0.0030 - learning_rate: 1.0000e-07

# %% [markdown]
# ### Visualizing results of the training

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Error [pixels]')
    plt.legend()
    plt.grid(True)

# %%
loss     = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.subplot(1, 2, 2)
plot_loss(history)
plt.title('MAE over Epochs')

plt.show()

# %% [markdown]
# # Performance
#
# Collect the results on the test set:

# %%
test_results = {}

test_results['model'] = model.evaluate(
    test_data_gen,
    steps=int(np.ceil(total_test / float(BATCH_SIZE))),
    verbose=0
)

pd.DataFrame(test_results, index=['Mean absolute error [pixels]']).T
# Out:
#        Mean absolute error [pixels]
# model                       0.00426

# %% [markdown]
# ### Make predictions
#
# You can now make predictions with the model on the test set using `Model.predict` and review the loss:

# %%
test_predictions = model.predict(
    test_data_gen,
    steps=int(np.ceil(total_test / float(BATCH_SIZE)))
)

# Collect true labels in the same order as the generator
test_labels = test_df[['shift_x', 'shift_y']].values
test_predictions = test_predictions[:len(test_labels)]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step

# %%
# Scatter plot: predicted vs. true for shift_x and shift_y
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

for i, label in enumerate(['shift_x', 'shift_y']):
    a = axes[i]
    a.set_aspect('equal')
    a.scatter(test_labels[:, i], test_predictions[:, i], alpha=0.5)
    lims = [test_labels[:, i].min(), test_labels[:, i].max()]
    a.set_xlim(lims)
    a.set_ylim(lims)
    a.plot(lims, lims, 'k--')
    a.set_xlabel(f'True Values [{label}]')
    a.set_ylabel(f'Predictions [{label}]')

plt.tight_layout()
plt.show()

# %% [markdown]
# Now, check the error distribution:

# %%
error_x = test_predictions[:, 0] - test_labels[:, 0]
error_y = test_predictions[:, 1] - test_labels[:, 1]

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(error_x, bins=25)
plt.xlabel('Prediction Error [shift_x]')
_ = plt.ylabel('Count')

plt.subplot(1, 2, 2)
plt.hist(error_y, bins=25)
plt.xlabel('Prediction Error [shift_y]')
_ = plt.ylabel('Count')

plt.tight_layout()
plt.show()

print(f'MAE shift_x : {np.mean(np.abs(error_x)):.5f} pixels')
print(f'MAE shift_y : {np.mean(np.abs(error_y)):.5f} pixels')
# Out:
# MAE shift_x : 0.07556 pixels
# MAE shift_y : 0.07155 pixels

# %% [markdown]
# If you're happy with the model, save it for later use with `Model.save`:

# %%
model.save('subpixel_shift_model.keras')
model.save('/content/drive/MyDrive/Subpixel_Shift_CNN/subpixel_shift_model.keras')

# %% [markdown]
# If you reload the model, it gives identical output:

# %%
reloaded = tf.keras.models.load_model('subpixel_shift_model.keras')

test_results['reloaded'] = reloaded.evaluate(
    test_data_gen,
    steps=int(np.ceil(total_test / float(BATCH_SIZE))),
    verbose=0
)

pd.DataFrame(test_results, index=['Mean absolute error [pixels]']).T
# Out:
#           Mean absolute error [pixels]
# model                          0.00426
# reloaded                       0.00426

# %% [markdown]
# **Test Model with Random Image from the Test Dataset**

# %%
# 1. Grab one random row from your test dataframe
random_sample = test_df.sample(n=1).iloc[0]

img_path = random_sample['filepath']
true_x = random_sample['shift_x']
true_y = random_sample['shift_y']

# 2. Load and preprocess the image
# We use the IMG_HEIGHT (300) and IMG_WIDTH (363) you set earlier
img = tf.keras.utils.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
img_array = tf.keras.utils.img_to_array(img)
img_array = img_array / 255.0  # Crucial: apply the 1./255 scaling!

# 3. Add a "batch" dimension
# Keras models ALWAYS expect a batch. We change shape from (300, 363, 3) to (1, 300, 363, 3)
img_batch = np.expand_dims(img_array, axis=0)

# 4. Make the prediction!
prediction = model.predict(img_batch, verbose=0)
pred_x, pred_y = prediction[0]

# 5. Print the results
print("--- PREDICTION RESULTS ---")
print(f"File: {img_path.split('/')[-1]}")
print(f"True X Shift : {true_x:.5f}")
print(f"Pred X Shift : {pred_x:.5f}")
print(f"-> X Error   : {abs(true_x - pred_x):.5f} pixels\n")

print(f"True Y Shift : {true_y:.5f}")
print(f"Pred Y Shift : {pred_y:.5f}")
print(f"-> Y Error   : {abs(true_y - pred_y):.5f} pixels")

# Optional: Show the image just so you know what you're looking at
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# --- PREDICTION RESULTS ---
# File: test_3.10688_4.97753.png
# True X Shift : 3.10688
# Pred X Shift : 3.11153
# -> X Error   : 0.00465 pixels
#
# True Y Shift : 4.97753
# Pred Y Shift : 5.05398
# -> Y Error   : 0.07645 pixels

# %% [markdown]
# ## Conclusion
#
# This notebook introduced a few techniques to handle a CNN regression problem. Here are a few more tips that may help:
#
# - Mean absolute error (MAE) is the standard loss for regression problems. It is less sensitive to outliers than MSE.
# - The CNN architecture follows the Dogs vs Cats structure exactly (4× Conv+MaxPool blocks), with the final `softmax` classification layer replaced by a linear `Dense(2)` output — one value for `shift_x` and one for `shift_y`.
# - Data augmentation was restricted to **photometric only** (brightness, very mild zoom). Spatial transforms like flips and rotations are unsafe for this task as they would change the true shift values.
# - The dedicated 100-image validation set is passed directly as `validation_data` to monitor overfitting throughout training — no random splitting needed.
